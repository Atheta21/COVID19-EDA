# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data= pd.read_csv(r"D:\powerbi\country_wise_latest.csv")

# %%
data
# Out:
#          Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# 0           Afghanistan      36263    1269      25198    9796        106
# 1               Albania       4880     144       2745    1991        117
# 2               Algeria      27973    1163      18837    7973        616
# 3               Andorra        907      52        803      52         10
# 4                Angola        950      41        242     667         18
# ..                  ...        ...     ...        ...     ...        ...
# 182  West Bank and Gaza      10621      78       3752    6791        152
# 183      Western Sahara         10       1          8       1          0
# 184               Yemen       1691     483        833     375         10
# 185              Zambia       4552     140       2815    1597         71
# 186            Zimbabwe       2704      36        542    2126        192
#
#      New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# ...

# %%
data.head()
# Out:
#   Country/Region  Confirmed  Deaths  Recovered  Active  New cases  New deaths  \
# 0    Afghanistan      36263    1269      25198    9796        106          10
# 1        Albania       4880     144       2745    1991        117           6
# 2        Algeria      27973    1163      18837    7973        616           8
# 3        Andorra        907      52        803      52         10           0
# 4         Angola        950      41        242     667         18           1
#
#    New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 0             18                3.50                  69.49
# 1             63                2.95                  56.25
# 2            749                4.16                  67.34
# 3              0                5.73                  88.53
# 4              0                4.32                  25.47
#
#    Deaths / 100 Recovered  Confirmed last week  1 week change  \
# 0                    5.04                35526            737
# ...

# %%
data.columns
# Out:
# Index(['Country/Region', 'Confirmed', 'Deaths', 'Recovered', 'Active',
#        'New cases', 'New deaths', 'New recovered', 'Deaths / 100 Cases',
#        'Recovered / 100 Cases', 'Deaths / 100 Recovered',
#        'Confirmed last week', '1 week change', '1 week % increase',
#        'WHO Region'],
#       dtype='object')

# %%
data.tail()
# Out:
#          Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# 182  West Bank and Gaza      10621      78       3752    6791        152
# 183      Western Sahara         10       1          8       1          0
# 184               Yemen       1691     483        833     375         10
# 185              Zambia       4552     140       2815    1597         71
# 186            Zimbabwe       2704      36        542    2126        192
#
#      New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 182           2              0                0.73                  35.33
# 183           0              0               10.00                  80.00
# 184           4             36               28.56                  49.26
# 185           1            465                3.08                  61.84
# 186           2             24                1.33                  20.04
#
#      Deaths / 100 Recovered  Confirmed last week  1 week change  \
# ...

# %%
data.describe()
# Out:
#           Confirmed         Deaths     Recovered        Active     New cases  \
# count  1.870000e+02     187.000000  1.870000e+02  1.870000e+02    187.000000
# mean   8.813094e+04    3497.518717  5.063148e+04  3.400194e+04   1222.957219
# std    3.833187e+05   14100.002482  1.901882e+05  2.133262e+05   5710.374790
# min    1.000000e+01       0.000000  0.000000e+00  0.000000e+00      0.000000
# 25%    1.114000e+03      18.500000  6.265000e+02  1.415000e+02      4.000000
# 50%    5.059000e+03     108.000000  2.815000e+03  1.600000e+03     49.000000
# 75%    4.046050e+04     734.000000  2.260600e+04  9.149000e+03    419.500000
# max    4.290259e+06  148011.000000  1.846641e+06  2.816444e+06  56336.000000
#
#         New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# count   187.000000     187.000000          187.000000             187.000000
# mean     28.957219     933.812834            3.019519              64.820535
# ...

# %%
data.isnull().sum()
# Out:
# Country/Region            0
# Confirmed                 0
# Deaths                    0
# Recovered                 0
# Active                    0
# New cases                 0
# New deaths                0
# New recovered             0
# Deaths / 100 Cases        0
# Recovered / 100 Cases     0
# Deaths / 100 Recovered    0
# Confirmed last week       0
# 1 week change             0
# 1 week % increase         0
# WHO Region                0
# dtype: int64

# %% [markdown]
# RELATING VARIABLES WITH SCATTER PLOTS

# %%
sns.relplot(x="Confirmed" , y="Deaths",hue="Recovered", data=data)

# %%
sns.pairplot(data)

# %%
data.columns
# Out:
# Index(['Country/Region', 'Confirmed', 'Deaths', 'Recovered', 'Active',
#        'New cases', 'New deaths', 'New recovered', 'Deaths / 100 Cases',
#        'Recovered / 100 Cases', 'Deaths / 100 Recovered',
#        'Confirmed last week', '1 week change', '1 week % increase',
#        'WHO Region'],
#       dtype='object')

# %%
sns.relplot(x='Active', y='Confirmed', kind='line',data= data)

# %%
sns.set(style="whitegrid")
plt.rcParams["figure.figsize"] = (10, 6)

# %%
top_confirmed = data.sort_values("Confirmed", ascending=False).head(10)
plt.figure()
sns.barplot(data=top_confirmed, x="Confirmed", y="Country/Region", palette="Reds_r")
plt.title("Top 10 Countries by Confirmed Cases")
plt.show()
# Out:
# C:\Users\Aastha\AppData\Local\Temp\ipykernel_11348\877747094.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=top_confirmed, x="Confirmed", y="Country/Region", palette="Reds_r")

# %%
plt.figure()
sns.histplot(data["Deaths / 100 Cases"], bins=20, kde=True, color="red")
plt.title("Distribution of Deaths per 100 Cases")
plt.show()

# %% [markdown]
# plot fig, plot histogram and use death/100 case data, bins=20 means Divides the range of data into 20 intervals (bars).
# kde=True--Adds a kernel density estimate (a smooth curve over the histogram).
# color="red"--Makes both the histogram and KDE curve red.

# %%
plt.figure()
sns.histplot(data["Recovered / 100 Cases"], bins=20, kde=True, color="green")
plt.title("Distribution of Recovered per 100 Cases")
plt.show()

# %%
region_grouped = data.groupby("WHO Region").sum(numeric_only=True).sort_values("Confirmed", ascending=False)
plt.figure()
sns.barplot(x=region_grouped["Confirmed"], y=region_grouped.index, palette="Blues_d")
plt.title("WHO Region-wise Confirmed Cases")
plt.show()
# Out:
# C:\Users\Aastha\AppData\Local\Temp\ipykernel_11348\829237959.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=region_grouped["Confirmed"], y=region_grouped.index, palette="Blues_d")

# %%
corr = data.select_dtypes(include=["float64", "int64"]).corr()
plt.figure(figsize=(12, 8))
sns.heatmap(corr, annot=True, cmap="coolwarm", linewidths=0.5)
plt.title("Correlation Heatmap of Numerical Features")
plt.show()

# %% [markdown]
# corr()=preparing the data to visualize which numeric columns are strongly related (e.g., Confirmed ↔ Deaths) .corr--The correlation matrix to plot (2D table of values).annot=True--Displays the actual correlation values inside each square.cmap="coolwarm"	A color map: blue = negative correlation, red = positive. linewidths=0.5--Adds thin lines between squares to improve visibility.

# %% [markdown]
# ###  Exploratory Data Analysis (EDA)
#
# ###  1. Top 10 Countries by Confirmed Cases
# - Bar chart showing the countries with the highest number of confirmed COVID-19 cases.
#
# ###  2. Distribution of Deaths per 100 Cases
# - Histogram that visualizes the distribution of death rates across countries.
# - Helps identify countries with higher fatality ratios.
#
# ###  3. Distribution of Recovered per 100 Cases
# - Histogram showing how well different countries managed recoveries.
# - Peaks near 60-90% show many countries had decent recovery rates.
#
# ###  4. WHO Region-wise Confirmed Cases
# - Bar chart aggregating confirmed cases by WHO region.
# - Helps identify regional disparities in total case counts.
#
# ###  5. Correlation Heatmap
# - Shows the relationship between different numerical variables.
# - Strong correlations:
#   - Confirmed ↔ Deaths
#   - Confirmed ↔ Recovered
#   - New Cases ↔ Active Cases
# - Inverse relation seen between Death Rate and Recovery Rate.
#
# ##  Key Insights
#
# - **Top Countries**: The United States, India, and Brazil lead in confirmed and death counts.
# - **Recovery Rate**: Many countries exhibit recovery rates between 60–90%.
# - **Death Rate**: Countries with underdeveloped healthcare or delayed intervention show death rates above 5%.
# - **Regional Spread**: The Americas and Europe have the highest case loads, while Africa shows comparatively lower numbers.
# - **Correlations**: Strong positive correlation between confirmed and deaths indicates proportional fatality with spread.
